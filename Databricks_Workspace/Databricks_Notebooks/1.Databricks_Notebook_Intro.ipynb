# %% [markdown]
# # Introduction to Notebooks
# This notebook gives introduction to Notebooks !

# %%
def show(name: str):
  print('Welcome to Databricks :',name)

# %%
show('Pavan')

# %%
# %sql
select 'Hellow from Databricks SQL!'
