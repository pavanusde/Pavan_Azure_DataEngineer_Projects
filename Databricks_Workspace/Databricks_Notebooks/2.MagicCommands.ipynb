# %% [markdown]
# # Databricks Magic Commands
# - **%python, %scala, %R , $Sql** Switch to differnt languages for a specific cell
# - **%fs:**   Run file sytem controls
# - **%sh:**   Run shell commands (Driver Node Only)
# - **%pip:**  Install Python Libraries
# - **%run:**  Include/import another notebook in to the current notebook

# %% [markdown]
# ### **%fs: Run File System Commands**

# %%
# %fs
ls /databricks-datasets/

# %% [markdown]
# ### **%sh:**   Run shell commands (Driver Node Only)

# %%
# %sh ps

# %% [markdown]
# ### **%pip:**  Install Python Libraries

# %%
# %pip list

# %%
# %pip install faker

# %% [markdown]
# ### %run:  Include/import another notebook in to the current notebook

# %%
# %run "/Workspace/Users/pavanusde@yahoo.com/Pavan_Azure_DataEngineer_Projects/Databricks_Workspace/Databricks_Notebooks/2.1 Environment Variables and Functions"

# %%
env

# %%
print_env_info()
